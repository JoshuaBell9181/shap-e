# %%
import torch

from shap_e.diffusion.sample import sample_latents
from shap_e.diffusion.gaussian_diffusion import diffusion_from_config
from shap_e.models.download import load_model, load_config
from shap_e.util.notebooks import create_pan_cameras, decode_latent_images, gif_widget

# %%
device = torch.device('mps' if torch.mps.is_available() else 'cpu')

# %%
xm = load_model('transmitter', device=device)
model = load_model('text300M', device=device)
diffusion = diffusion_from_config(load_config('diffusion'))

# %%
batch_size = 4
guidance_scale = 15.0
prompt = "a shark"

latents = sample_latents(
    batch_size=batch_size,
    model=model,
    diffusion=diffusion,
    guidance_scale=torch.tensor(guidance_scale, dtype=torch.float32),  # Ensure float32
    model_kwargs=dict(texts=[prompt] * batch_size),
    progress=True,
    clip_denoised=True,
    use_fp16=False,  # Disable FP16 (not supported on MPS)
    use_karras=True,
    karras_steps=64,
    sigma_min=torch.tensor(1e-3, dtype=torch.float32),  # Force float32
    sigma_max=torch.tensor(160, dtype=torch.float32),   # Force float32
    s_churn=torch.tensor(0, dtype=torch.float32)        # Force float32
)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 guidance_scale = 15.0
#       3 prompt = "a shark"
# ----> 5 latents = sample_latents(
#       6     batch_size=batch_size,
#       7     model=model,
#       8     diffusion=diffusion,
#       9     guidance_scale=torch.tensor(guidance_scale, dtype=torch.float32),  # Ensure float32
#      10     model_kwargs=dict(texts=[prompt] * batch_size),
#      11     progress=True,
#      12     clip_denoised=True,
#      13     use_fp16=False,  # Disable FP16 (not supported on MPS)
#      14     use_karras=True,
#      15     karras_steps=64,
#      16     sigma_min=torch.tensor(1e-3, dtype=torch.float32),  # Force float32
#      17     sigma_max=torch.tensor(160, dtype=torch.float32),   # Force float32
#      18     s_churn=torch.tensor(0, dtype=torch.float32)        # Force float32
#      19 )
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/sample.py:62, in sample_latents(batch_size, model, diffusion, model_kwargs, guidance_scale, clip_denoised, use_fp16, use_karras, karras_steps, sigma_min, sigma_max, s_churn, device, progress)
#      60 with torch.autocast(device_type=device.type, enabled=use_fp16):
#      61     if use_karras:
# ---> 62         samples = karras_sample(
#      63             diffusion=diffusion,
#      64             model=model,
#      65             shape=sample_shape,
#      66             steps=karras_steps,
#      67             clip_denoised=clip_denoised,
#      68             model_kwargs=model_kwargs,
#      69             device=device,
#      70             sigma_min=sigma_min,
#      71             sigma_max=sigma_max,
#      72             s_churn=s_churn,
#      73             guidance_scale=guidance_scale,
#      74             progress=progress,
#      75         )
#      76     else:
#      77         internal_batch_size = batch_size
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/k_diffusion.py:113, in karras_sample(*args, **kwargs)
#     111 def karras_sample(*args, **kwargs):
#     112     last = None
# --> 113     for x in karras_sample_progressive(*args, **kwargs):
#     114         last = x["x"]
#     115     return last
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/k_diffusion.py:181, in karras_sample_progressive(diffusion, model, shape, steps, clip_denoised, progress, model_kwargs, device, sigma_min, sigma_max, rho, sampler, s_churn, s_tmin, s_tmax, s_noise, guidance_scale)
#     178 else:
#     179     guided_denoiser = denoiser
# --> 181 for obj in sample_fn(
#     182     guided_denoiser,
#     183     x_T,
#     184     sigmas,
#     185     progress=progress,
#     186     **sampler_args,
#     187 ):
#     188     if isinstance(diffusion, GaussianDiffusion):
#     189         yield diffusion.unscale_out_dict(obj)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/utils/_contextlib.py:57, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      54         else:
#      55             # Pass the last request to the generator and get its response
#      56             with ctx_factory():
# ---> 57                 response = gen.send(request)
#      59 # We let the exceptions raised above by the generator's `.throw` or
#      60 # `.send` methods bubble up to our caller, except for StopIteration
#      61 except StopIteration as e:
#      62     # The generator informed us that it is done: take whatever its
#      63     # returned value (if any) was and indicate that we're done too
#      64     # by returning it (see docs for python's return-statement).
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/k_diffusion.py:275, in sample_heun(denoiser, x, sigmas, progress, s_churn, s_tmin, s_tmax, s_noise)
#     272 else:
#     273     # Heun's method
#     274     x_2 = x + d * dt
# --> 275     denoised_2 = denoiser(x_2, sigmas[i + 1] * s_in)
#     276     d_2 = to_d(x_2, sigmas[i + 1], denoised_2)
#     277     d_prime = (d + d_2) / 2
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/k_diffusion.py:173, in karras_sample_progressive.<locals>.guided_denoiser(x_t, sigma)
#     171 x_t = th.cat([x_t, x_t], dim=0)
#     172 sigma = th.cat([sigma, sigma], dim=0)
# --> 173 x_0 = denoiser(x_t, sigma)
#     174 cond_x_0, uncond_x_0 = th.split(x_0, len(x_0) // 2, dim=0)
#     175 x_0 = uncond_x_0 + guidance_scale * (cond_x_0 - uncond_x_0)
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/k_diffusion.py:160, in karras_sample_progressive.<locals>.denoiser(x_t, sigma)
#     159 def denoiser(x_t, sigma):
# --> 160     _, denoised = model.denoise(
#     161         x_t, sigma, clip_denoised=clip_denoised, model_kwargs=model_kwargs
#     162     )
#     163     return denoised
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/k_diffusion.py:105, in GaussianToKarrasDenoiser.denoise(self, x_t, sigmas, clip_denoised, model_kwargs)
#      99 t = th.tensor(
#     100     [self.sigma_to_t(sigma) for sigma in sigmas.cpu().numpy()],
#     101     dtype=th.long,
#     102     device=sigmas.device,
#     103 )
#     104 c_in = append_dims(1.0 / (sigmas**2 + 1) ** 0.5, x_t.ndim)
# --> 105 out = self.diffusion.p_mean_variance(
#     106     self.model, x_t * c_in, t, clip_denoised=clip_denoised, model_kwargs=model_kwargs
#     107 )
#     108 return None, out["pred_xstart"]
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/diffusion/gaussian_diffusion.py:333, in GaussianDiffusion.p_mean_variance(self, model, x, t, clip_denoised, denoised_fn, model_kwargs)
#     331 B, C = x.shape[:2]
#     332 assert t.shape == (B,)
# --> 333 model_output = model(x, t, **model_kwargs)
#     334 if isinstance(model_output, tuple):
#     335     model_output, extra = model_output
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/generation/latent_diffusion.py:21, in SplitVectorDiffusion.forward(self, x, t, **kwargs)
#      19 h = x.reshape(x.shape[0], self.n_ctx, -1).permute(0, 2, 1)
#      20 pre_channels = h.shape[1]
# ---> 21 h = self.wrapped(h, t, **kwargs)
#      22 assert (
#      23     h.shape[1] == pre_channels * 2
#      24 ), "expected twice as many outputs for variance prediction"
#      25 eps, var = torch.chunk(h, 2, dim=1)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/generation/transformer.py:298, in CLIPImagePointDiffusionTransformer.forward(self, x, t, images, texts, embeddings)
#     295 clip_embed = self.clip_embed(clip_out)
#     297 cond = [(clip_embed, self.token_cond), (t_embed, self.time_token_cond)]
# --> 298 return self._forward_with_cond(x, cond)
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/generation/transformer.py:231, in PointDiffusionTransformer._forward_with_cond(self, x, cond_as_token)
#     228     h = torch.cat(extra_tokens + [h], dim=1)
#     230 h = self.ln_pre(h)
# --> 231 h = self.backbone(h)
#     232 h = self.ln_post(h)
#     233 if len(extra_tokens):
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/generation/transformer.py:147, in Transformer.forward(self, x)
#     145 def forward(self, x: torch.Tensor):
#     146     for block in self.resblocks:
# --> 147         x = block(x)
#     148     return x
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/generation/transformer.py:109, in ResidualAttentionBlock.forward(self, x)
#     108 def forward(self, x: torch.Tensor):
# --> 109     x = x + self.attn(self.ln_1(x))
#     110     x = x + self.mlp(self.ln_2(x))
#     111     return x
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/generation/transformer.py:42, in MultiheadAttention.forward(self, x)
#      40 def forward(self, x):
#      41     x = self.c_qkv(x)
# ---> 42     x = checkpoint(self.attention, (x,), (), True)
#      43     x = self.c_proj(x)
#      44     return x
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/nn/checkpoint.py:24, in checkpoint(func, inputs, params, flag)
#      22 if flag:
#      23     args = tuple(inputs) + tuple(params)
# ---> 24     return CheckpointFunction.apply(func, len(inputs), *args)
#      25 else:
#      26     return func(*inputs)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/amp/autocast_mode.py:503, in custom_fwd.<locals>.decorate_fwd(*args, **kwargs)
#     501 if cast_inputs is None:
#     502     args[0]._fwd_used_autocast = torch.is_autocast_enabled(device_type)
# --> 503     return fwd(*args, **kwargs)
#     504 else:
#     505     autocast_context = torch.is_autocast_enabled(device_type)
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/nn/checkpoint.py:39, in CheckpointFunction.forward(ctx, run_function, length, *args)
#      37 ctx.save_for_backward(*input_tensors, *input_params)
#      38 with torch.no_grad():
# ---> 39     output_tensors = ctx.run_function(*input_tensors)
#      40 return output_tensors
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/playground/text-to-3d/shap-e/shap_e/models/generation/transformer.py:75, in QKVMultiheadAttention.forward(self, qkv)
#      73 qkv = qkv.view(bs, n_ctx, self.heads, -1)
#      74 q, k, v = torch.split(qkv, attn_ch, dim=-1)
# ---> 75 weight = torch.einsum(
#      76     "bthc,bshc->bhts", q * scale, k * scale
#      77 )  # More stable with f16 than dividing afterwards
#      78 wdtype = weight.dtype
#      79 weight = torch.softmax(weight.float(), dim=-1).type(wdtype)
#
# File ~/.pyenv/versions/textTo3d/lib/python3.11/site-packages/torch/functional.py:210, in einsum(*args)
#     203     # Overwriting reason:
#     204     # This dispatches to two ATen functions depending on the type of
#     205     # split_size_or_sections. The branching code is in _tensor.py, which we
#     206     # call here.
#     207     return tensor.split(split_size_or_sections, dim)
# --> 210 def einsum(*args: Any) -> Tensor:
#     211     r"""einsum(equation, *operands) -> Tensor
#     212
#     213     Sums the product of the elements of the input :attr:`operands` along dimensions specified using a notation
#    (...)
#     351                 [ 0.3311,  5.5201, -3.0356]])
#     352     """
#     353     import torch.backends.opt_einsum as opt_einsum
#
# KeyboardInterrupt:

# %%
render_mode = 'nerf' # you can change this to 'stf'
size = 64 # this is the size of the renders; higher values take longer to render.

cameras = create_pan_cameras(size, device)
for i, latent in enumerate(latents):
    images = decode_latent_images(xm, latent, cameras, rendering_mode=render_mode)
    display(gif_widget(images))

# %%
# Example of saving the latents as meshes.
from shap_e.util.notebooks import decode_latent_mesh

for i, latent in enumerate(latents):
    t = decode_latent_mesh(xm, latent).tri_mesh()
    with open(f'example_mesh_{i}.ply', 'wb') as f:
        t.write_ply(f)
    with open(f'example_mesh_{i}.obj', 'w') as f:
        t.write_obj(f)
